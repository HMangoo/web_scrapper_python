# %%
# %cd "/content/drive/MyDrive/스펙이될만한것들/web_scrapper"
# Out:
# /content/drive/MyDrive/스펙이될만한것들/web_scrapper

# %%
# !pwd
# Out:
# /content/drive/MyDrive/스펙이될만한것들/web_scrapper

# %%
from indeed import get_jobs as get_indeed_jobs
from so import get_jobs as get_so_jobs
from save import save_to_df
import pandas as pd

# %%
print("indeed")
indeed_jobs = get_indeed_jobs()
print("stack overflow")
so_jobs = get_so_jobs()
# Out:
# indeed
# Scrapping page 0
# Scrapping page 1
# Scrapping page 2
# Scrapping page 3
# Scrapping page 4
# stack overflow
# Scrapping page 0
# Scrapping page 1
# Scrapping page 2
# Scrapping page 3
# Scrapping page 4
# Scrapping page 5
# Scrapping page 6
# Scrapping page 7
# Scrapping page 8
# Scrapping page 9
# Scrapping page 10
# Scrapping page 11
# Scrapping page 12
# Scrapping page 13
# Scrapping page 14
# Scrapping page 15
# Scrapping page 16
# Scrapping page 17
# Scrapping page 18
# Scrapping page 19
# Scrapping page 20
# Scrapping page 21
# Scrapping page 22
# Scrapping page 23
# Scrapping page 24
# Scrapping page 25
# Scrapping page 26
# Scrapping page 27

# %%
# csv파일로 저장
jobs = so_jobs + indeed_jobs
dataframe = pd.DataFrame(jobs, columns=['title', 'company', 'location', 'link'])
dataframe.to_csv("/content/drive/MyDrive/스펙이될만한것들/web_scrapper/jobs.csv", header=False, index=False)
